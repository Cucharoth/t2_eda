# %%
import pandas as pd


df_user_repo = pd.read_csv('../data/user_repos.csv')
df_user_repo.head()
# Out:
#    Unnamed: 0         id                           node_id           name  \
# 0           0      24363      MDEwOlJlcG9zaXRvcnkyNDM2Mw==    ar_fixtures
# 1           1  874556416                      R_kgDONCCsAA      baseballr
# 2           2      52452      MDEwOlJlcG9zaXRvcnk1MjQ1Mg==    basic_model
# 3           3    1441793      MDEwOlJlcG9zaXRvcnkxNDQxNzkz         bigapp
# 4           4   68860702  MDEwOlJlcG9zaXRvcnk2ODg2MDcwMg==  blog-comments
#
#                 full_name  private                                   html_url  \
# 0    topfunky/ar_fixtures    False    https://github.com/topfunky/ar_fixtures
# 1      topfunky/baseballr    False      https://github.com/topfunky/baseballr
# 2    topfunky/basic_model    False    https://github.com/topfunky/basic_model
# 3         topfunky/bigapp    False         https://github.com/topfunky/bigapp
# 4  topfunky/blog-comments    False  https://github.com/topfunky/blog-comments
#
# ...

# %%
df_my_df = df_user_repo.
